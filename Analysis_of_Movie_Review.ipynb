# %% [markdown]
# #***Data***
# The term 'data' in a project broadly refers to all the information and documents collected, analyzed, and utilized to plan, execute, monitor, and control the project. This data plays a pivotal role in making informed decisions, managing risks, and ensuring, that the project objective are met. By leveraging this information, project managers can take well-informed decisions and steer the project towards a successful conclusion.

# %% [markdown]
# #***Importing Python Libraries***
# To proceed with data analysis and visualization in Python, we must important modules such as pandas, numpy, seaborn, and matplotlib. Pandas is used for data analysis, numpy for calculating n-dimensional arrays, and seaborn and matplotlib for data visualization.

# %%
# Importing Matplotlib
import matplotlib.pyplot as plt
# Importing Numpy
import numpy as np
# Importing Pandas
import pandas as pd
# Importing Seaborn
import seaborn as sb

# %% [markdown]
# #***Importing Machine Learning Libraries***
# To perform machine learning tasks such as creating regression lines, splitting the lines, and predicting values, we need to import some important modules from the sci-kit-learn library (sklearn). These modules include train_test_split, DecisionTreeClassifier, classification_report, confusion_matrix, RandomForestClassifier.

# %%
# Importing Train Test Split
from sklearn.model_selection import train_test_split
# Importing Logistic Regression
from sklearn.linear_model import LogisticRegression
# Importing K Neighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
# Importing K Means Clustering
from sklearn.cluster import KMeans
# Importing Accuracy Score, Confusion Matrix, and Classification Report
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #***Reading the Data Set***
# Usually, datasets come in CSV files, but in this case, the file is in Excel format. To read this Excel file in Python, we will use the Pandas library.

# %%
# Read the Data Frame
df = pd.read_excel('/content/drive/MyDrive/Data Set of Analysis of Movie Reviews.xlsx')
df.head()
# Out:
#    Movie Budget (INR) Movie Release Date  Movie Genre  Movie Name  \
# 0           350000000         2023-08-24            1           0
# 1          2700000000         2023-12-22            0           2
# 2           400000000         2023-12-07            3           1
# 3           400000000         2023-12-07            3           1
# 4         11364150000         2023-10-06            2           4
#
#    Movie Rating                                             Review  \
# 0           4.0                                      #OneTimeWatch
# 1           4.3  Great drama, action, and storytelling. Charact...
# 2           4.8             #SuperDirection #GreatActing #WowMusic
# 3           4.8                                       #GreatActing
# 4           2.9  The user watched the original Exorcist and fou...
#
#   Review Date     Review Name  Review Rating  Review Source  Review Type
# 0  2023-08-25           Aasha              5              0            1
# 1  2023-12-23  Abhiaero-56016             10              1            2
# 2  2023-12-08      Anjaneyulu              8              0            2
# 3  2023-12-09          Ankith             10              0            2
# 4  2023-10-08     Axmxd-68629             10              1            2

# %% [markdown]
# #***Data Cleaning***
# Data cleaning is a meticulous and time-consuming process that requires a keen eye for detail, an in-depth understanding of the domain, and the use of appropriate tools and techniques. It is an indispensable step in any data-related project, as accurate and reliable data is crucial to making informed decisions and achieving precise results in data analysis, machine learning, and other data-driven tasks. Without proper data cleaning, the output of a project can be severely impacted by inaccuracies and inconsistencies in the data. Therefore, it is imperative to invest time and effort in data cleaning to ensure the quality and integrity of the data.

# %% [markdown]
# #***Dropping Duplicate Values of the Data Set***
# It is common for a dataset to contain duplicate rows. These duplicates only make the dataset larger and have no value for data analysis. Therefore, it is necessary to identify and drop any duplicate rows in the dataset.

# %%
# Dropping the Duplicate Values
df = df.drop_duplicates()
df.head()
# Out:
#    Movie Budget (INR) Movie Release Date  Movie Genre  Movie Name  \
# 0           350000000         2023-08-24            1           0
# 1          2700000000         2023-12-22            0           2
# 2           400000000         2023-12-07            3           1
# 3           400000000         2023-12-07            3           1
# 4         11364150000         2023-10-06            2           4
#
#    Movie Rating                                             Review  \
# 0           4.0                                      #OneTimeWatch
# 1           4.3  Great drama, action, and storytelling. Charact...
# 2           4.8             #SuperDirection #GreatActing #WowMusic
# 3           4.8                                       #GreatActing
# 4           2.9  The user watched the original Exorcist and fou...
#
#   Review Date     Review Name  Review Rating  Review Source  Review Type
# 0  2023-08-25           Aasha              5              0            1
# 1  2023-12-23  Abhiaero-56016             10              1            2
# 2  2023-12-08      Anjaneyulu              8              0            2
# 3  2023-12-09          Ankith             10              0            2
# 4  2023-10-08     Axmxd-68629             10              1            2

# %% [markdown]
# #***Getting to know what type of Data Set we have***
#
# To extract information from the dataset, we utilize a specific function after analyzing the data. During this analysis, we also take note of the null value count for each feature and determine the data type of the features present in the dataset.

# %%
# Getting to know our Data Set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Budget (INR)  100 non-null    int64
#  1   Movie Release Date  100 non-null    datetime64[ns]
#  2   Movie Genre         100 non-null    int64
#  3   Movie Name          100 non-null    int64
#  4   Movie Rating        100 non-null    float64
#  5   Review              100 non-null    object
#  6   Review Date         100 non-null    datetime64[ns]
#  7   Review Name         100 non-null    object
#  8   Review Rating       100 non-null    int64
#  9   Review Source       100 non-null    int64
#  10  Review Type         100 non-null    int64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(2)
# memory usage: 8.7+ KB

# %% [markdown]
# #***Describing the Data Set***
# We can utilize the describe() function to provide an overview of the Data Set and calculate various statistics for each data point in the feature.

# %%
# Describing the Data Set
df.describe().T
# Out:
#                     count                 mean                  min  \
# Movie Budget (INR)  100.0         4290030000.0          350000000.0
# Movie Release Date    100  2023-10-23 19:12:00  2023-08-24 00:00:00
# Movie Genre         100.0                  2.0                  0.0
# Movie Name          100.0                  2.0                  0.0
# Movie Rating        100.0                 3.92                  2.9
# Review Date           100  2023-10-25 07:12:00  2023-08-25 00:00:00
# Review Rating       100.0                 7.05                  1.0
# Review Source       100.0                  0.5                  0.0
# Review Type         100.0                 1.44                  0.0
#
#                                     25%                  50%  \
# Movie Budget (INR)          400000000.0         2700000000.0
# Movie Release Date  2023-09-29 00:00:00  2023-10-06 00:00:00
# Movie Genre                         1.0                  2.0
# Movie Name                          1.0                  2.0
# Movie Rating                        3.6                  4.0
# Review Date         2023-09-30 00:00:00  2023-10-07 12:00:00
# Review Rating                       5.0                  8.0
# Review Source                       0.0                  0.5
# Review Type                         1.0                  2.0
#
#                                     75%                  max  \
# Movie Budget (INR)         6636000000.0        11364150000.0
# Movie Release Date  2023-12-07 00:00:00  2023-12-22 00:00:00
# Movie Genre                         3.0                  4.0
# Movie Name                          3.0                  4.0
# Movie Rating                        4.3                  4.8
# Review Date         2023-12-09 00:00:00  2023-12-24 00:00:00
# Review Rating                      10.0                 10.0
# Review Source                       1.0                  1.0
# Review Type                         2.0                  2.0
#
#                                   std
# Movie Budget (INR)  4233849031.295043
# Movie Release Date                NaN
# Movie Genre                  1.421338
# Movie Name                   1.421338
# Movie Rating                 0.646357
# Review Date                       NaN
# Review Rating                3.115212
# Review Source                0.502519
# Review Type                  0.832666

# %% [markdown]
# #***Handling Null values***
#
# To improve accuracy, we address any null values found in the dataset using the isnull() function.

# %%
# Handling Null Values
df.isnull().sum()
# Out:
# Movie Budget (INR)    0
# Movie Release Date    0
# Movie Genre           0
# Movie Name            0
# Movie Rating          0
# Review                0
# Review Date           0
# Review Name           0
# Review Rating         0
# Review Source         0
# Review Type           0
# dtype: int64

# %% [markdown]
# #***Finding all the unique values in the Data Set***
#
# In pandas, there exists a method for discovering every distinct value within a dataset. This can be accomplished by utilizing the nunique() function.

# %%
# Finding all the Unique value in the Data Set
df.nunique()
# Out:
# Movie Budget (INR)     5
# Movie Release Date     5
# Movie Genre            5
# Movie Name             5
# Movie Rating           5
# Review                88
# Review Date           10
# Review Name           77
# Review Rating         10
# Review Source          2
# Review Type            3
# dtype: int64

# %% [markdown]
# #***Exploratory Data Analysis(EDA)***
# Exploratory Data Analysis (EDA) involves using both statistical and visual methods, and it can be an iterative process. It plays a crucial role in setting the foundation for any data analysis or modeling work. By thoroughly understanding the data through EDA, analysts can make more informed decisions about how to proceed and how to extract valuable insights from the dataset.

# %% [markdown]
# #***Pair plot***
#
# A grid of axis is created by this function to display the pairwise relationship between the features in the dataset. The row's y-axis and column's x-axis are utilized to plot the correlation between each feature.

# %%
# Pair Plot of the Data Set
sb.pairplot(df)

# %% [markdown]
# Key Insights:
# * Movie Genre, Movie Rating, and Review Rating all variables are positively correlated with the target variable (Review Type).
# *	Movie Budget (INR), Movie Name, and Review Source all variables are negatively correlated with the target variable (Review Type).

# %% [markdown]
# #***Scatter Plot***
#
# This plot shows how two sets of data are related to each other.

# %% [markdown]
# #***Scatter Plot of Review Rating and Movie Budget (INR)***

# %%
# Scatter Plot of Review Rating and Movie Budget (INR)
df.plot(kind='scatter', x='Movie Budget (INR)', y='Review Rating', edgecolor='blue')
plt.title('Scatter Plot: Review Rating vs Movie Budget (INR)')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Movie Budget (INR)', fontsize = 12)
plt.ylabel('Review Rating', fontsize = 12)
plt.show()

# %% [markdown]
# Key Insights:
#
# * 	Movie Budget (INR) has a negative correlation with Review Rating, i.e., Movie Budget (INR) has a decreasing trend with Review Rating, i.e., as Movie Budget (INR) decreases Review Rating also decreases.

# %% [markdown]
# #***Scatter Plot of Review Rating and Movie Genre***

# %%
# Scatter Plot of Review Rating and Movie Genre
df.plot(kind='scatter', x='Movie Genre', y='Review Rating', edgecolor='blue')
plt.title('Scatter Plot: Review Rating vs Movie Genre')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Movie Genre', fontsize = 12)
plt.ylabel('Review Rating', fontsize = 12)
plt.show()

# %% [markdown]
# Key Insights:
# * Movie Genre has a positive correlation with Review Rating, i.e., Movie Genre has an increasing trend with Review Rating, i.e., as Movie Genre increases Review Rating also increases.

# %% [markdown]
# #***Scatter Plot of Review Rating and Movie Name***

# %%
# Scatter Plot of Review Rating and Movie Name
df.plot(kind='scatter', x='Movie Name', y='Review Rating', edgecolor='blue')
plt.title('Scatter Plot: Review Rating vs Movie Name')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Movie Name', fontsize = 12)
plt.ylabel('Review Rating', fontsize = 12)
plt.show()

# %% [markdown]
# Key Insights:
# * Movie Name has a negative correlation with Review Rating, i.e., Movie Name has a decreasing trend with Review Rating, i.e., as Movie Name decreases Review Rating also decreases.

# %% [markdown]
# #***Scatter Plot of Review Rating and Movie Rating***

# %%
# Scatter Plot of Review Rating and Movie Rating
df.plot(kind='scatter', x='Movie Rating', y='Review Rating', edgecolor='blue')
plt.title('Scatter Plot: Review Rating vs Movie Rating')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Movie Rating', fontsize = 12)
plt.ylabel('Review Rating', fontsize = 12)
plt.show()

# %% [markdown]
# Key Insights:
# * Movie Rating has a positive correlation with Review Rating, i.e., Movie Rating has an increasing trend with Review Rating, i.e., as Movie Rating increases Review Rating also increases.

# %% [markdown]
# #***Correlation Plot***
#
# The correlation plot is a visual representation of the correlation coefficient between variables, which is displayed in the form of a matrix-like table. To visualize the correlation between variables, we use the Seaborn library to plot the correlation plot. This plot displays a one-to-one relationship between variables, with each variable showing its relationship with another variable. Upon observing the heatmap, we can see that Age has a strong correlation with Amount.

# %%
plt.figure(figsize = [12, 12])
# Ploting Correlation Plot
sb.heatmap(df.corr(numeric_only=True), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Key Insights:
# *   Strong Correlation: Movie Budget (INR) and Movie Name, Movie Budget (INR) and Movie Rating. and Review Rating and Review Type.
# *   Moderate Correlation: Movie Budget (INR) and Review Source, Movie Name and Movie Rating, Movie Rating and Review Source, Review Rating and Review Source, and Review Source and Review Type.
# *   The rest not stated have a weak correlation.

# %% [markdown]
# Let's plot the outlier that's present in the dataset.
#
# #***Box plot***
#
# In the boxplot, it can be observed that there are black dots present on both the left and right sides of the lines. These dots represent outliers that are present in a specific feature of the dataset.

# %%
l = ['Movie Budget (INR)', 'Movie Genre', 'Movie Name', 'Movie Rating', 'Review Rating', 'Review Source', 'Review Type']
for i in l:
  sb.boxplot(x = df[i])
  plt.show()

# %% [markdown]
# #***Applying Classification***
# Classification in a project involves sorting or categorizing data or items into predefined groups based on their characteristics. It's a fundamental process used in various applications, such as sorting emails into spam and non-spam, classifying text sentiment, or identifying diseases from medical test results. This helps in data organization and decision-making.

# %% [markdown]
# #***Splitting the Data***
# To split the training and testing parts, we can use the scikit-learn module train_test_split

# %%
x = df[['Movie Budget (INR)', 'Movie Genre', 'Movie Name', 'Movie Rating', 'Review Rating', 'Review Source']]
y = df['Review Type']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# The program has a list of independent variables stored in x, while the dependent variable is in y. The independent variables are Movie Budget (INR), Movie Genre, Movie Name, Movie Rating, Review Rating, and Review Source. The dependent variable is Review Type.

# %% [markdown]
# #***Applying Model***

# %% [markdown]
# #***Logistic Regression***

# %%
model = LogisticRegression(C = 0.001)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print('Confusion Matrix: ', cm)
print('Classification report: ', report)
# Out:
# Accuracy: 0.75
# Confusion Matrix:  [[ 0  0  3]
#  [ 0  0  2]
#  [ 0  0 15]]
# Classification report:                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.00      0.00      0.00         2
#            2       0.75      1.00      0.86        15
#
#     accuracy                           0.75        20
#    macro avg       0.25      0.33      0.29        20
# weighted avg       0.56      0.75      0.64        20

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (8, 6))
sb.heatmap(cm, annot = True, cmap = 'BuGn', fmt = 'd', cbar = True)
plt.title('Confusion Matrix for Logistic Regression')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Predicted', fontsize = 12)
plt.ylabel('Actual', fontsize = 12)
plt.show()

# %% [markdown]
# #***K-Nearest Neighbors (KNN) Classifier***

# %%
k = 1
model = KNeighborsClassifier(n_neighbors = k)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print('Confusion Matrix: ', cm)
print('Classification report: ', report)
# Out:
# Accuracy: 0.95
# Confusion Matrix:  [[ 3  0  0]
#  [ 0  1  1]
#  [ 0  0 15]]
# Classification report:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      0.50      0.67         2
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.95        20
#    macro avg       0.98      0.83      0.88        20
# weighted avg       0.95      0.95      0.94        20

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (8, 6))
sb.heatmap(cm, annot = True, cmap = 'YlOrBr', fmt = 'd', cbar = True)
plt.title('Confusion Matrix for K - Nearest Neighbor')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Predicted', fontsize = 12)
plt.ylabel('Actual', fontsize = 12)
plt.show()

# %% [markdown]
# #***Ridge Logistic Regression***

# %%
ridge_model = LogisticRegression(penalty = 'l2', C = 0.001)
ridge_model.fit(x_train, y_train)
y_pred = ridge_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print('Confusion Matrix: ', cm)
print('Classification report: ', report)
# Out:
# Accuracy: 0.72
# Confusion Matrix:  [[ 0  0  4]
#  [ 0  0  3]
#  [ 0  0 18]]
# Classification report:                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         3
#            2       0.72      1.00      0.84        18
#
#     accuracy                           0.72        25
#    macro avg       0.24      0.33      0.28        25
# weighted avg       0.52      0.72      0.60        25

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
y_pred = ridge_model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (8, 6))
sb.heatmap(cm, annot = True, cmap = 'cubehelix', fmt = 'd', cbar = True)
plt.title('Confusion Matrix for Ridge Logistic Regression')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Predicted', fontsize = 12)
plt.ylabel('Actual', fontsize = 12)
plt.show()

# %% [markdown]
# #***K-Means Clusterings Classifier***

# %%
k = 2
kmeans = KMeans(n_clusters = k)
clusters = kmeans.fit_predict(x_test)
y_pred = kmeans.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print('Confusion Matrix: ', cm)
print('Classification report: ', report)
# Out:
# Accuracy: 0.15
# Confusion Matrix:  [[2 1 0]
#  [1 1 0]
#  [6 9 0]]
# Classification report:                precision    recall  f1-score   support
#
#            0       0.22      0.67      0.33         3
#            1       0.09      0.50      0.15         2
#            2       0.00      0.00      0.00        15
#
#     accuracy                           0.15        20
#    macro avg       0.10      0.39      0.16        20
# weighted avg       0.04      0.15      0.07        20

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 42)
y_pred = kmeans.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (8, 6))
sb.heatmap(cm, annot = True, cmap = 'Pastel1', fmt = 'd', cbar = True)
plt.title('Confusion Matrix for K - Means Clusterings')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Predicted', fontsize = 12)
plt.ylabel('Actual', fontsize = 12)
plt.show()
